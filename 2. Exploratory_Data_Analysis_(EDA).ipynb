# %% [markdown]
# <a href="https://colab.research.google.com/github/kcymae/Computational-TCell-Epitope-Analysis/blob/main/Exploratory_Data_Analysis_(EDA).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Initial tuff**

# %%
import pandas as pd

# Load directly from repo (works for everyone)
combined_df = pd.read_csv("epitope_prediction_combined.csv")
print(combined_df.head())
# Out:
#      peptide       allele    score  percentile_rank
# 0  MFVFLVLLP  HLA-A*02:01  0.00013             31.0
# 1  FVFLVLLPL  HLA-A*02:01  0.04690              2.2
# 2  VFLVLLPLV  HLA-A*02:01  0.00903              5.2
# 3  FLVLLPLVS  HLA-A*02:01  0.01370              4.3
# 4  LVLLPLVSS  HLA-A*02:01  0.00392              7.7

# %% [markdown]
# Alternative: Load directly from Github

# %%
import pandas as pd

# Load directly from your GitHub repo (no manual upload needed!)
url = "https://raw.githubusercontent.com/kcymae/Project-/main/epitope_prediction_combined.csv"
combined_df = pd.read_csv(url)
print(combined_df.head())
# Out:
#      peptide       allele    score  percentile_rank
# 0  MFVFLVLLP  HLA-A*02:01  0.00013             31.0
# 1  FVFLVLLPL  HLA-A*02:01  0.04690              2.2
# 2  VFLVLLPLV  HLA-A*02:01  0.00903              5.2
# 3  FLVLLPLVS  HLA-A*02:01  0.01370              4.3
# 4  LVLLPLVSS  HLA-A*02:01  0.00392              7.7

# %% [markdown]
# Clone your repo

# %%
# !git clone https://github.com/kcymae/Computational-TCell-Epitope-Analysis.git
# !cd Computational-TCell-Epitope-Analysis && git add EDA_Analysis.ipynb && git commit -m "Add EDA notebook" && git push origin main
# Out:
# fatal: destination path 'Computational-TCell-Epitope-Analysis' already exists and is not an empty directory.
# fatal: pathspec 'EDA_Analysis.ipynb' did not match any files
